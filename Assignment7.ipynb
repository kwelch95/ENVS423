# %%
dogs = {"Scout": "Howly Loud girl", "Pixie": "Barky Little Chicken", "Pillow": "Itchy smol white gremlin"}

print("\nScout:")
print(dogs["Scout"])

print()

print("\nPixie:")
print(dogs["Pixie"])

print()

print("\nPillow:")
print(dogs["Pillow"])


for puppers, description in dogs.items():
    print("\nDogger: %s" % puppers)
    print("Description: %s" % description)

for puppers, description in dogs.items():
    print(puppers + " is a " + description + ".")
dogs["Scout Brümhilda Dobby Marie"] = dogs["Scout"]
del dogs["Scout"]

dogs["Maggie"] = "beautiful golden nugget of perfection"
dogs["Roxie"] = "clingly sweet old girl"
del dogs["Pixie"]
del dogs["Pillow"]

print(dogs)
print()
for puppers, description in dogs.items():
    print(puppers + " is a " + description + ".")
# Out:
# Scout:
# Howly Loud girl
#
#
# Pixie:
# Barky Little Chicken
#
#
# Pillow:
# Itchy smol white gremlin
#
# Dogger: Pillow
# Description: Itchy smol white gremlin
#
# Dogger: Scout
# Description: Howly Loud girl
#
# Dogger: Pixie
# Description: Barky Little Chicken
# Pillow is a Itchy smol white gremlin.
# Scout is a Howly Loud girl.
# Pixie is a Barky Little Chicken.
# {'Scout Brümhilda Dobby Marie': 'Howly Loud girl', 'Maggie': 'beautiful golden nugget of perfection', 'Roxie': 'clingly sweet old girl'}
#
# Scout Brümhilda Dobby Marie is a Howly Loud girl.
# Maggie is a beautiful golden nugget of perfection.
# Roxie is a clingly sweet old girl.

# %%
#Make a dictionary where the keys are the names of weight lifting exercises, and the values are the number of times you did that exercise.
#Use a for loop to print out a series of statements such as "I did 10 bench presses".
#Modify one of the values in your dictionary, to represent doing more of that exercise.
#Use a for loop to print out a series of statements such as "I did 10 bench presses".
#Add a new key-value pair to your dictionary.
#Use a for loop to print out a series of statements such as "I did 10 bench presses".
#Remove one of the key-value pairs from your dictionary.
#Use a for loop to print out a series of statements such as "I did 10 bench presses".
#Bonus: Use a function to do all of the looping and printing in this problem.

exercise = {"handstands": "27", "cat dead lifts": "3", "backflips": "239"}
for stuff, counts in exercise.items():
    print("I possibly entertained doing " + counts + " " + stuff + ". " )
exercise["handstands"] = "36.4"
print()
for stuff, counts in exercise.items():
    print("I possibly entertained doing " + counts + " " + stuff + ". " )
print()    
del exercise["cat dead lifts"]
print()
for stuff, counts in exercise.items():
    print("I possibly entertained doing " + counts + " " + stuff + ". " )
# Out:
# I possibly entertained doing 239 backflips.
# I possibly entertained doing 27 handstands.
# I possibly entertained doing 3 cat dead lifts.
#
# I possibly entertained doing 239 backflips.
# I possibly entertained doing 36.4 handstands.
# I possibly entertained doing 3 cat dead lifts.
#
#
# I possibly entertained doing 239 backflips.
# I possibly entertained doing 36.4 handstands.

# %%
#Wikipedia has a list of the tallest mountains in the world, with each mountain's elevation. Pick five mountains from this list.
#Create a dictionary with the mountain names as keys, and the elevations as values.
#Print out just the mountains' names, by looping through the keys of your dictionary.
#Print out just the mountains' elevations, by looping through the values of your dictionary.
#Print out a series of statements telling how tall each mountain is: "Everest is 8848 meters tall."
#Revise your output, if necessary.
#Make sure there is an introductory sentence describing the output for each loop you write.
#Make sure there is a blank line between each group of statements.


genericsoundingmountains = {"North Mountain": "969 meters", "Great Blue Hill": "193.5 meters", "Blue Mountain": "452 meters", "Broad Peak": "8,051 meters", "Sunset Peak": "4,745 meters", "White Mountain Peak": "3,432 meters", "Snowmass Mountain": "4,295 meters", "North/South Twin Peaks": "Who cares?"}
print("Most Generic Sonuding Mountains and Their Elevations")
for mountains, elevation in genericsoundingmountains.items():
    print("\nMountain: %s" % mountains)
    print("Elevation: %s" % elevation)

    
print()
print("The Elevations only of the most generic sounding mountains in the world")
for mountains, elevation in genericsoundingmountains.items():
    print(elevation)
    
print()
print("The most generic sounding mountains are:")
for mountains, elevation in genericsoundingmountains.items():
    print(mountains + ", which is " + elevation + " tall. " )

#Mountain Heights 2
#Revise your final output from Mountain Heights, so that the information is listed in alphabetical order by each mountain's name.
#That is, print out a series of statements telling how tall each mountain is: "Everest is 8848 meters tall."
#Make sure your output is in alphabetical order.

print()
print("The most generic sounding mountains are:")
for mountains, elevation in sorted(genericsoundingmountains.items()):
    print(mountains + ", which is " + elevation + " tall. " )
# Out:
# Most Generic Sonuding Mountains and Their Elevations
#
# Mountain: Sunset Peak
# Elevation: 4,745 meters
#
# Mountain: Broad Peak
# Elevation: 8,051 meters
#
# Mountain: Blue Mountain
# Elevation: 452 meters
#
# Mountain: Snowmass Mountain
# Elevation: 4,295 meters
#
# Mountain: White Mountain Peak
# Elevation: 3,432 meters
#
# Mountain: Great Blue Hill
# Elevation: 193.5 meters
#
# Mountain: North Mountain
# Elevation: 969 meters
#
# Mountain: North/South Twin Peaks
# Elevation: Who cares?
#
# The Elevations only of the most generic sounding mountains in the world
# 4,745 meters
# 8,051 meters
# 452 meters
# 4,295 meters
# 3,432 meters
# 193.5 meters
# 969 meters
# Who cares?
#
# The most generic sounding mountains are:
# Sunset Peak, which is 4,745 meters tall.
# Broad Peak, which is 8,051 meters tall.
# Blue Mountain, which is 452 meters tall.
# Snowmass Mountain, which is 4,295 meters tall.
# White Mountain Peak, which is 3,432 meters tall.
# ...

# %%
#Create a new dictionary, where the keys of the dictionary are still the mountains' names. This time however, the values of the dictionary should be a list of each mountain's elevation in meters, and then in feet: {'everest': [8848, 29029]}
#Print out just the mountains' names, by looping through the keys of your dictionary.
#Print out just the mountains' elevations in meters, by looping through the values of your dictionary and pulling out the first number from each list.
#Print out just the mountains' elevations in feet, by looping through the values of your dictionary and pulling out the second number from each list.
#Print out a series of statements telling how tall each mountain is: "Everest is 8848 meters tall, or 29029 feet."
genericsoundingmountains = {"North Mountain": {"SI": "969 meters", "archaic": "3,179 feet"} , "Great Blue Hill": {"SI": "193.5 meters", "archaic": "635 feet"}, "Blue Mountain": {"SI": "452 meters", "archaic": "1,483 feet"}, "Broad Peak": {"SI": "8,051 meters", "archaic": "26,414 feet"}, "Sunset Peak": {"SI": "4,745 meters", "archaic": "15,568 feet"} , "White Mountain Peak": {"SI": "3,432 meters", "archaic": "14,245 feet"}, "Snowmass Mountain": {"SI": "4,295 meters", "archaic": "14,091 feet"}, "North/South Twin Peaks": {"SI":"Who cares?", "archaic": "Seriously why are we still using feet?"}}

print("Generic Sounding Mountains and their Elevations in meters")
for mountains, heights in genericsoundingmountains.items():
      print(mountains + " which is " + heights["SI"] + " tall.")
print()
print("Generic Sounding Mountains and their Elevations in feet")
for mountains, heights in genericsoundingmountains.items():
      print(mountains + " which is " + heights["archaic"] + " tall.")

print()
print("Generic Sounding Mountains and their Elevations")
for mountains, heights in genericsoundingmountains.items():
      print(mountains + " which is " + heights["SI"] + " tall, or " + heights["archaic"] + ".")

#Mountain Heights 4
#This is one more extension of Mountain Heights.
#Create a new dictionary, where the keys of the dictionary are once again the mountains' names. This time, the values of the dictionary are another dictionary. This dictionary should contain the elevation in either meters or feet, and the range that contains the mountain. For example: {'everest': {'elevation': 8848, 'range': 'himalaya'}}.
#Print out just the mountains' names.
#Print out just the mountains' elevations.
#Print out just the range for each mountain.
#Print out a series of statements that say everything you know about each mountain: "Everest is an 8848-meter tall mountain in the Himalaya range."

genericsoundingmountains2 = {"North Mountain": {"SI": "969 meters", "archaic": "3,179 feet", "range": "The Catskills, New York State, USA, North America"} , "Great Blue Hill": {"SI": "193.5 meters", "archaic": "635 feet", "range": "Massachusetts, USA, North America"}, "Blue Mountain": {"SI": "452 meters", "archaic": "1,483 feet", "range": "Ontario, Canada, North America"}, "Broad Peak": {"SI": "8,051 meters", "archaic": "26,414 feet", "range": "The Karakoram Range, Pakistan/China, Asia"}, "Sunset Peak": {"SI": "4,745 meters", "archaic": "15,568 feet", "range": "The Himalayas, Kashmir Valley, India, Asia"} , "White Mountain Peak": {"SI": "3,432 meters", "archaic": "14,245 feet", "range": "White Mountains, California, USA, North America"}, "Snowmass Mountain": {"SI": "4,295 meters", "archaic": "14,091 feet", "range": "The Elk Mountains, Colorado, USA"}, "North/South Twin Peaks": {"SI": "Who cares?", "archaic": "Seriously why are we still using feet?", "range": "Canada, or whatever/s"}}
print()
print("Generic Sounding Mountains and their Elevations and locations")
for mountains, deets in genericsoundingmountains2.items():
      print(mountains + " which is " + deets["SI"] + " tall, or " + deets["archaic"] + ". This mountain is in " + deets["range"] + ". ")
# Out:
# Generic Sounding Mountains and their Elevations in meters
# Sunset Peak which is 4,745 meters tall.
# Broad Peak which is 8,051 meters tall.
# Blue Mountain which is 452 meters tall.
# Snowmass Mountain which is 4,295 meters tall.
# White Mountain Peak which is 3,432 meters tall.
# Great Blue Hill which is 193.5 meters tall.
# North Mountain which is 969 meters tall.
# North/South Twin Peaks which is Who cares? tall.
#
# Generic Sounding Mountains and their Elevations in feet
# Sunset Peak which is 15,568 feet tall.
# Broad Peak which is 26,414 feet tall.
# Blue Mountain which is 1,483 feet tall.
# Snowmass Mountain which is 14,091 feet tall.
# White Mountain Peak which is 14,245 feet tall.
# Great Blue Hill which is 635 feet tall.
# North Mountain which is 3,179 feet tall.
# North/South Twin Peaks which is Seriously why are we still using feet? tall.
#
# Generic Sounding Mountains and their Elevations
# Sunset Peak which is 4,745 meters tall, or 15,568 feet.
# ...
